# %%
import pandas as pd

# %%
# zillow steps to take:

# ----------- TRANSFORM - clean the data --------------

# get rid of the city and city code and metro (column a b and c) - Mark and Anthony - done by Tuesday
# get rid of population rank - Mark and Anthony - done by Tuesday

# format column headers for readability - Mark and Anthony - done by Tuesday

# %%
price_url = 'https://raw.githubusercontent.com/randallwvr90/bootcamp_project_2/Anthony/csv/price.csv'

# %%
price_df = pd.read_csv(price_url)

# %%
# get rid of the city and city code and metro (column a b and c) -
# get rid of population rank - Mark and Anthony 
price_df.drop(['City Code', 'City', 'Metro', 'Population Rank'], axis=1, inplace=True)

# %%
# format column headers for readability

headers = price_df.columns

new_headers = []
for  header in headers:
    new_headers.append(header.replace(" ", ""))

    
price_df.columns = new_headers 
price_df
# Out:
#                      County State  Nov-10  Dec-10  Jan-11  Feb-11  Mar-11  \
# 0                 Anchorage    AK     NaN     NaN     NaN     NaN  1787.0
# 1         Matanuska Susitna    AK     NaN     NaN     NaN     NaN  1581.0
# 2      Fairbanks North Star    AK     NaN     NaN     NaN     NaN  1554.0
# 3         Matanuska Susitna    AK     NaN     NaN     NaN     NaN  1571.0
# 4           Kenai Peninsula    AK     NaN     NaN     NaN     NaN  1533.0
# ...                     ...   ...     ...     ...     ...     ...     ...
# 13126               Natrona    WY     NaN     NaN     NaN     NaN     NaN
# 13127               Laramie    WY     NaN     NaN     NaN     NaN     NaN
# 13128               Laramie    WY     NaN     NaN     NaN     NaN     NaN
# 13129              Big Horn    WY     NaN     NaN     NaN     NaN     NaN
# 13130               Natrona    WY     NaN     NaN     NaN     NaN     NaN
#
#        Apr-11  May-11  Jun-11  ...  Apr-16  May-16  Jun-16  Jul-16  Aug-16  \
# 0      1798.0  1806.0  1813.0  ...    1966    1960    1951    1937    1925
# 1      1576.0  1585.0  1597.0  ...    1757    1761    1767    1767    1763
# 2      1534.0  1532.0  1526.0  ...    1721    1735    1740    1721    1708
# 3      1552.0  1542.0  1539.0  ...    1736    1735    1729    1716    1697
# 4      1500.0  1484.0  1481.0  ...    1406    1413    1419    1430    1443
# ...       ...     ...     ...  ...     ...     ...     ...     ...     ...
# 13126     NaN     NaN     NaN  ...    1709    1681    1646    1610    1591
# 13127     NaN     NaN     NaN  ...    1406    1379    1354    1318    1281
# 13128     NaN     NaN     NaN  ...    1405    1364    1329    1289    1262
# 13129     NaN     NaN     NaN  ...    1063    1052    1040    1017     991
# 13130     NaN     NaN     NaN  ...    1326    1308    1296    1293    1280
#
#        Sep-16  Oct-16  Nov-16  Dec-16  Jan-17
# 0        1916    1912    1907    1903    1900
# 1        1753    1735    1715    1703    1692
# 2        1705    1716    1716    1710    1701
# 3        1678    1654    1638    1621    1603
# 4        1445    1422    1401    1373    1351
# ...       ...     ...     ...     ...     ...
# 13126    1585    1600    1601    1577    1543
# 13127    1257    1247    1227    1207    1207
# 13128    1254    1259    1256    1251    1268
# 13129     954     920     893     889     897
# 13130    1260    1233    1205    1184    1176
#
# [13131 rows x 77 columns]
